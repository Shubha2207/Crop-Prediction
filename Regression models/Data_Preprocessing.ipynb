# %%
import pandas as pd

# %% [markdown]
# ## remove '=' value from production column and remove empty rows

# %%
dataset = pd.read_csv('/content/apy.csv')

# %%
dataset
# Out:
#         State_Name District_Name  Crop_Year  ...       Crop      Area  Production
# 0      Maharashtra    AHMEDNAGAR     1997.0  ...      Maize       1.0        1113
# 1      Maharashtra    AHMEDNAGAR     1997.0  ...  Arhar/Tur   17600.0        6300
# 2      Maharashtra    AHMEDNAGAR     1997.0  ...      Bajra  274100.0      152800
# 3      Maharashtra    AHMEDNAGAR     1997.0  ...       Gram   40800.0       18600
# 4      Maharashtra    AHMEDNAGAR     1997.0  ...      Jowar     900.0        1100
# ...            ...           ...        ...  ...        ...       ...         ...
# 12623  Maharashtra      YAVATMAL     2014.0  ...      Jowar    4000.0        3300
# 12624  Maharashtra      YAVATMAL     2014.0  ...      Maize    1300.0         200
# 12625  Maharashtra      YAVATMAL     2014.0  ...      Wheat   29100.0       26800
# 12626  Maharashtra      YAVATMAL     2014.0  ...  Groundnut    9400.0       11500
# ...

# %%
list1 = dataset['District_Name'].values
print(list1)
# Out:
# ['AHMEDNAGAR' 'AHMEDNAGAR' 'AHMEDNAGAR' ... 'YAVATMAL' 'YAVATMAL'
#  'YAVATMAL']

# %%
# intilize a null list
#list1 = dataset['District_Name'].values
#print(list1)
unique_list = []

def unique(list1):     
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)

unique(list1)

# %%
len(unique_list)
# Out:
# 35

# %%
unique_list
# Out:
# ['AHMEDNAGAR',
#  'AKOLA',
#  'AMRAVATI',
#  'AURANGABAD',
#  'BEED',
#  'BHANDARA',
#  'BULDHANA',
#  'CHANDRAPUR',
#  'DHULE',
#  'GADCHIROLI',
#  'GONDIA',
#  'HINGOLI',
#  'JALGAON',
#  'JALNA',
#  'KOLHAPUR',
#  'LATUR',
#  'MUMBAI',
#  'NAGPUR',
#  'NANDED',
#  'NANDURBAR',
#  'NASHIK',
#  'OSMANABAD',
#  'PALGHAR',
#  'PARBHANI',
#  'PUNE',
#  'RAIGAD',
#  'RATNAGIRI',
#  'SANGLI',
#  'SATARA',
#  'SINDHUDURG',
#  'SOLAPUR',
#  'THANE',
#  'WARDHA',
#  'WASHIM',
#  'YAVATMAL']

# %%
#<option value="1">AHMEDNAGAR</option>

temp = ['AHMEDNAGAR','AKOLA','AMRAVATI','AURANGABAD','BEED','BHANDARA','BULDHANA','CHANDRAPUR','DHULE','GADCHIROLI','GONDIA','HINGOLI','JALGAON','JALNA','KOLHAPUR','LATUR','MUMBAI','NAGPUR','NANDED','NANDURBAR','NASHIK','OSMANABAD','PALGHAR','PARBHANI','PUNE','RAIGAD','RATNAGIRI','SANGLI','SATARA','SINDHUDURG','SOLAPUR','THANE','WARDHA','WASHIM','YAVATMAL']

i = 1

for x in temp:
  print("<option value="+str(x)+">"+x+"</option>")
  i += 1
# Out:
# <option value=AHMEDNAGAR>AHMEDNAGAR</option>
# <option value=AKOLA>AKOLA</option>
# <option value=AMRAVATI>AMRAVATI</option>
# <option value=AURANGABAD>AURANGABAD</option>
# <option value=BEED>BEED</option>
# <option value=BHANDARA>BHANDARA</option>
# <option value=BULDHANA>BULDHANA</option>
# <option value=CHANDRAPUR>CHANDRAPUR</option>
# <option value=DHULE>DHULE</option>
# <option value=GADCHIROLI>GADCHIROLI</option>
# <option value=GONDIA>GONDIA</option>
# <option value=HINGOLI>HINGOLI</option>
# <option value=JALGAON>JALGAON</option>
# <option value=JALNA>JALNA</option>
# <option value=KOLHAPUR>KOLHAPUR</option>
# <option value=LATUR>LATUR</option>
# <option value=MUMBAI>MUMBAI</option>
# <option value=NAGPUR>NAGPUR</option>
# <option value=NANDED>NANDED</option>
# <option value=NANDURBAR>NANDURBAR</option>
# <option value=NASHIK>NASHIK</option>
# <option value=OSMANABAD>OSMANABAD</option>
# <option value=PALGHAR>PALGHAR</option>
# <option value=PARBHANI>PARBHANI</option>
# ...

# %%
temp = dataset[['Crop_Year','Season']].values
temp
type(temp)
# Out:
# numpy.ndarray

# %%
temp
# Out:
# array([[1997, 'Autumn     '],
#        [1997, 'Kharif     '],
#        [1997, 'Kharif     '],
#        ...,
#        [2014, 'Rabi       '],
#        [2014, 'Summer     '],
#        [2014, 'Whole Year ']], dtype=object)

# %%
filter = dataset['Production']!="="

dataset.where(filter, inplace=True)
dataset
# Out:
#         State_Name District_Name  Crop_Year  ...       Crop      Area  Production
# 0      Maharashtra    AHMEDNAGAR     1997.0  ...      Maize       1.0        1113
# 1      Maharashtra    AHMEDNAGAR     1997.0  ...  Arhar/Tur   17600.0        6300
# 2      Maharashtra    AHMEDNAGAR     1997.0  ...      Bajra  274100.0      152800
# 3      Maharashtra    AHMEDNAGAR     1997.0  ...       Gram   40800.0       18600
# 4      Maharashtra    AHMEDNAGAR     1997.0  ...      Jowar     900.0        1100
# ...            ...           ...        ...  ...        ...       ...         ...
# 12623  Maharashtra      YAVATMAL     2014.0  ...      Jowar    4000.0        3300
# 12624  Maharashtra      YAVATMAL     2014.0  ...      Maize    1300.0         200
# 12625  Maharashtra      YAVATMAL     2014.0  ...      Wheat   29100.0       26800
# 12626  Maharashtra      YAVATMAL     2014.0  ...  Groundnut    9400.0       11500
# ...

# %%
# data_district_wise = list()

# for i in range(0,35):
#   data_district_wise.append(dataset)

# %%
# data_district_wise = dataset
# filter = data_district_wise['District_Name']=="AHMEDNAGAR"
# data_district_wise.where(filter, inplace=True)

# %%
# for i in range (0,35):
#   filter = data_district_wise[i]['District_Name']==str(unique_list[i])
#   data_district_wise[i].where(filter, inplace=True)
#   print(filter)
#   filter.drop(filter.index[:])

# %%
dataset.dropna()
# Out:
#         State_Name District_Name  Crop_Year  ...       Crop      Area  Production
# 0      Maharashtra    AHMEDNAGAR     1997.0  ...      Maize       1.0        1113
# 1      Maharashtra    AHMEDNAGAR     1997.0  ...  Arhar/Tur   17600.0        6300
# 2      Maharashtra    AHMEDNAGAR     1997.0  ...      Bajra  274100.0      152800
# 3      Maharashtra    AHMEDNAGAR     1997.0  ...       Gram   40800.0       18600
# 4      Maharashtra    AHMEDNAGAR     1997.0  ...      Jowar     900.0        1100
# ...            ...           ...        ...  ...        ...       ...         ...
# 12623  Maharashtra      YAVATMAL     2014.0  ...      Jowar    4000.0        3300
# 12624  Maharashtra      YAVATMAL     2014.0  ...      Maize    1300.0         200
# 12625  Maharashtra      YAVATMAL     2014.0  ...      Wheat   29100.0       26800
# 12626  Maharashtra      YAVATMAL     2014.0  ...  Groundnut    9400.0       11500
# ...

# %%
dataset.to_csv(r'C:\file.csv', index=False)

# %% [markdown]
# ## Sanitize Crop column... Remove alternatives eg Arhar/Tur then remove substring '/tur'

# %%
dataset_2 = pd.read_excel('Removed empty rows.xlsx')

# %%
dataset_2
# Out:
#         State_Name District_Name  Crop_Year  ...       Crop    Area  Production
# 0      Maharashtra    AHMEDNAGAR       1997  ...      Maize       1      1113.0
# 1      Maharashtra    AHMEDNAGAR       1997  ...  Arhar/Tur   17600      6300.0
# 2      Maharashtra    AHMEDNAGAR       1997  ...      Bajra  274100    152800.0
# 3      Maharashtra    AHMEDNAGAR       1997  ...       Gram   40800     18600.0
# 4      Maharashtra    AHMEDNAGAR       1997  ...      Jowar     900      1100.0
# ...            ...           ...        ...  ...        ...     ...         ...
# 12493  Maharashtra      YAVATMAL       2014  ...      Jowar    4000      3300.0
# 12494  Maharashtra      YAVATMAL       2014  ...      Maize    1300       200.0
# 12495  Maharashtra      YAVATMAL       2014  ...      Wheat   29100     26800.0
# 12496  Maharashtra      YAVATMAL       2014  ...  Groundnut    9400     11500.0
# 12497  Maharashtra      YAVATMAL       2014  ...  Sugarcane    8100    553700.0
#
# ...

# %%
crop_list = dataset_2['Crop'].values
len(crop_list)
# Out:
# 12498

# %%
# intilize a null list
distinct_crop = []

def unique(crop_list):     
    # traverse for all elements
    for x in crop_list:
        # check if exists in unique_list or not
        if x not in distinct_crop:
            distinct_crop.append(x)

unique(crop_list)

# %%
len(distinct_crop)
# Out:
# 34

# %%
distinct_crop
# Out:
# ['Maize',
#  'Arhar/Tur',
#  'Bajra',
#  'Gram',
#  'Jowar',
#  'Moong(Green Gram)',
#  'Pulses total',
#  'Ragi',
#  'Rice',
#  'Sugarcane',
#  'Total foodgrain',
#  'Urad',
#  'Other  Rabi pulses',
#  'Wheat',
#  'Cotton(lint)',
#  'Castor seed',
#  'Groundnut',
#  'Niger seed',
#  'Other Cereals & Millets',
#  'Other Kharif pulses',
#  'Sesamum',
#  'Soyabean',
#  'Sunflower',
#  'Linseed',
#  'Safflower',
#  'Small millets',
#  'Rapeseed &Mustard',
#  'other oilseeds',
#  'Banana',
#  'Grapes',
#  'Mango',
#  'Onion',
#  'Tomato',
#  'Tobacco']

# %%
dataset_2.loc[dataset_2['Crop'] == 'Arhar/Tur', ['Crop']] = 'Pigeon Peas'
dataset_2.loc[dataset_2['Crop'] == 'Moong(Green Gram)', ['Crop']] = 'mung bean'
dataset_2.loc[dataset_2['Crop'] == 'Pulses total', ['Crop']] = 'Lentil'
dataset_2.loc[dataset_2['Crop'] == 'Total foodgrain', ['Crop']] = 'Foodgrains'
dataset_2.loc[dataset_2['Crop'] == 'Urad', ['Crop']] = 'Black gram'
dataset_2.loc[dataset_2['Crop'] == 'Other  Rabi pulses', ['Crop']] = 'Chickpeas'
dataset_2.loc[dataset_2['Crop'] == 'Cotton(lint)', ['Crop']] = 'Cotton'
dataset_2.loc[dataset_2['Crop'] == 'Other Cereals & Millets', ['Crop']] = 'Millets'
dataset_2.loc[dataset_2['Crop'] == 'Other Kharif pulses', ['Crop']] = 'Pigeon Peas'
dataset_2.loc[dataset_2['Crop'] == 'Small millets', ['Crop']] = 'Millets'
dataset_2.loc[dataset_2['Crop'] == 'other oilseeds', ['Crop']] = 'Groundnuts'
dataset_2.loc[dataset_2['Crop'] == 'Rapeseed &Mustard', ['Crop']] = 'Rapeseed'

# %%
crop_list_2 = dataset_2['Crop'].values
distinct_crop_2 = []

def unique(crop_list_2):     
    # traverse for all elements
    for x in crop_list_2:
        # check if exists in unique_list or not
        if x not in distinct_crop_2:
            distinct_crop_2.append(x)

unique(crop_list_2)

# %%
distinct_crop_2
# Out:
# ['Maize',
#  'Pigeon Peas',
#  'Bajra',
#  'Gram',
#  'Jowar',
#  'mung bean',
#  'Lentil',
#  'Ragi',
#  'Rice',
#  'Sugarcane',
#  'Foodgrains',
#  'Black gram',
#  'Chickpeas',
#  'Wheat',
#  'Cotton',
#  'Castor seed',
#  'Groundnut',
#  'Niger seed',
#  'Millets',
#  'Sesamum',
#  'Soyabean',
#  'Sunflower',
#  'Linseed',
#  'Safflower',
#  'Rapeseed',
#  'Groundnuts',
#  'Banana',
#  'Grapes',
#  'Mango',
#  'Onion',
#  'Tomato',
#  'Tobacco']

# %%
dataset_2.to_csv(r'Crop Sanitized.csv', index=False)

# %% [markdown]
# ## separate the dataset districtwise

# %%
dataset_3 = pd.read_csv('Crop Sanitized.csv')

# %%
dataset_3.head()
# Out:
#     State_Name District_Name  Crop_Year  ...         Crop    Area  Production
# 0  Maharashtra    AHMEDNAGAR       1997  ...        Maize       1      1113.0
# 1  Maharashtra    AHMEDNAGAR       1997  ...  Pigeon Peas   17600      6300.0
# 2  Maharashtra    AHMEDNAGAR       1997  ...        Bajra  274100    152800.0
# 3  Maharashtra    AHMEDNAGAR       1997  ...         Gram   40800     18600.0
# 4  Maharashtra    AHMEDNAGAR       1997  ...        Jowar     900      1100.0
#
# [5 rows x 7 columns]

# %%
dataset_3.Season.unique()
# Out:
# array(['Autumn', 'Kharif', 'Rabi', 'Summer', 'Whole Year'], dtype=object)

# %%
dataset_3.Crop_Year.unique()
# Out:
# array([1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014])

# %%
x = 'AHMEDNAGAR'
ah = dataset_3[dataset_3['District_Name']==x]

# %%
ah
# Out:
#       State_Name District_Name  Crop_Year  ...         Crop    Area  Production
# 0    Maharashtra    AHMEDNAGAR       1997  ...        Maize       1      1113.0
# 1    Maharashtra    AHMEDNAGAR       1997  ...  Pigeon Peas   17600      6300.0
# 2    Maharashtra    AHMEDNAGAR       1997  ...        Bajra  274100    152800.0
# 3    Maharashtra    AHMEDNAGAR       1997  ...         Gram   40800     18600.0
# 4    Maharashtra    AHMEDNAGAR       1997  ...        Jowar     900      1100.0
# ..           ...           ...        ...  ...          ...     ...         ...
# 485  Maharashtra    AHMEDNAGAR       2014  ...    Chickpeas     900       200.0
# 486  Maharashtra    AHMEDNAGAR       2014  ...        Wheat   57200     85000.0
# 487  Maharashtra    AHMEDNAGAR       2014  ...    Groundnut    1600      2300.0
# 488  Maharashtra    AHMEDNAGAR       2014  ...        Maize     200       400.0
# 489  Maharashtra    AHMEDNAGAR       2014  ...    Sugarcane  122000  11761000.0
#
# ...

# %%
unique_districts = dataset_3['District_Name'].unique()

# %%
type(unique_districts)
# Out:
# numpy.ndarray

# %%
unique_districts
# Out:
# array(['AHMEDNAGAR', 'AKOLA', 'AMRAVATI', 'AURANGABAD', 'BEED',
#        'BHANDARA', 'BULDHANA', 'CHANDRAPUR', 'DHULE', 'GADCHIROLI',
#        'GONDIA', 'HINGOLI', 'JALGAON', 'JALNA', 'KOLHAPUR', 'LATUR',
#        'MUMBAI', 'NAGPUR', 'NANDED', 'NANDURBAR', 'NASHIK', 'OSMANABAD',
#        'PALGHAR', 'PARBHANI', 'PUNE', 'RAIGAD', 'RATNAGIRI', 'SANGLI',
#        'SATARA', 'SINDHUDURG', 'SOLAPUR', 'THANE', 'WARDHA', 'WASHIM',
#        'YAVATMAL'], dtype=object)

# %%
unique_districts[0]
# Out:
# 'AHMEDNAGAR'

# %%
info_districtwise = list()

for x in unique_districts:
  info_districtwise.append(dataset_3[dataset_3['District_Name']==x])

# %%
info_districtwise
# Out:
# [      State_Name District_Name  Crop_Year  ...         Crop    Area  Production
#  0    Maharashtra    AHMEDNAGAR       1997  ...        Maize       1      1113.0
#  1    Maharashtra    AHMEDNAGAR       1997  ...  Pigeon Peas   17600      6300.0
#  2    Maharashtra    AHMEDNAGAR       1997  ...        Bajra  274100    152800.0
#  3    Maharashtra    AHMEDNAGAR       1997  ...         Gram   40800     18600.0
#  4    Maharashtra    AHMEDNAGAR       1997  ...        Jowar     900      1100.0
#  ..           ...           ...        ...  ...          ...     ...         ...
#  485  Maharashtra    AHMEDNAGAR       2014  ...    Chickpeas     900       200.0
#  486  Maharashtra    AHMEDNAGAR       2014  ...        Wheat   57200     85000.0
#  487  Maharashtra    AHMEDNAGAR       2014  ...    Groundnut    1600      2300.0
#  488  Maharashtra    AHMEDNAGAR       2014  ...        Maize     200       400.0
#  489  Maharashtra    AHMEDNAGAR       2014  ...    Sugarcane  122000  11761000.0
#
# ...

# %%
info_districtwise[0]
# Out:
#       State_Name District_Name  Crop_Year  ...         Crop    Area  Production
# 0    Maharashtra    AHMEDNAGAR       1997  ...        Maize       1      1113.0
# 1    Maharashtra    AHMEDNAGAR       1997  ...  Pigeon Peas   17600      6300.0
# 2    Maharashtra    AHMEDNAGAR       1997  ...        Bajra  274100    152800.0
# 3    Maharashtra    AHMEDNAGAR       1997  ...         Gram   40800     18600.0
# 4    Maharashtra    AHMEDNAGAR       1997  ...        Jowar     900      1100.0
# ..           ...           ...        ...  ...          ...     ...         ...
# 485  Maharashtra    AHMEDNAGAR       2014  ...    Chickpeas     900       200.0
# 486  Maharashtra    AHMEDNAGAR       2014  ...        Wheat   57200     85000.0
# 487  Maharashtra    AHMEDNAGAR       2014  ...    Groundnut    1600      2300.0
# 488  Maharashtra    AHMEDNAGAR       2014  ...        Maize     200       400.0
# 489  Maharashtra    AHMEDNAGAR       2014  ...    Sugarcane  122000  11761000.0
#
# ...

# %%
type(info_districtwise[0])
# Out:
# pandas.core.frame.DataFrame

# %%
i = 0
for x in info_districtwise:
  name = unique_districts[i]
  i += 1 
  x.to_csv(name, index=False)

# %%
i = 0
idx = 0
name_list = ['Sumit','Ashu','Harsh','Shubham']
for x in unique_districts:
  print(x,end=", ")
  i += 1
  if(i==9):
    i = 0
    print(end=" ==>  ")
    print(name_list[idx])
    print()
    print()
    idx += 1

print(end=" ==>  ")
print(name_list[idx])
# Out:
# AHMEDNAGAR, AKOLA, AMRAVATI, AURANGABAD, BEED, BHANDARA, BULDHANA, CHANDRAPUR, DHULE,  ==>  Sumit
#
#
# GADCHIROLI, GONDIA, HINGOLI, JALGAON, JALNA, KOLHAPUR, LATUR, MUMBAI, NAGPUR,  ==>  Ashu
#
#
# NANDED, NANDURBAR, NASHIK, OSMANABAD, PALGHAR, PARBHANI, PUNE, RAIGAD, RATNAGIRI,  ==>  Harsh
#
#
# SANGLI, SATARA, SINDHUDURG, SOLAPUR, THANE, WARDHA, WASHIM, YAVATMAL,  ==>  Shubham

# %%
unique_crops = dataset_3['Crop'].unique()

# %%
unique_crops
# Out:
# array(['Maize', 'Pigeon Peas', 'Bajra', 'Gram', 'Jowar', 'mung bean',
#        'Lentil', 'Ragi', 'Rice', 'Sugarcane', 'Foodgrains', 'Black gram',
#        'Chickpeas', 'Wheat', 'Cotton', 'Castor seed', 'Groundnut',
#        'Niger seed', 'Millets', 'Sesamum', 'Soyabean', 'Sunflower',
#        'Linseed', 'Safflower', 'Rapeseed', 'Groundnuts', 'Banana',
#        'Grapes', 'Mango', 'Onion', 'Tomato', 'Tobacco'], dtype=object)

# %%
info_cropwise = list()

for x in unique_crops:
  info_cropwise.append(dataset_3[dataset_3['Crop']==x])

# %%
info_cropwise
# Out:
# [        State_Name District_Name  Crop_Year  Season   Crop  Area  Production
#  0      Maharashtra    AHMEDNAGAR       1997  Autumn  Maize     1      1113.0
#  5      Maharashtra    AHMEDNAGAR       1997  Kharif  Maize  4400      4700.0
#  14     Maharashtra    AHMEDNAGAR       1997    Rabi  Maize  6200      9100.0
#  17     Maharashtra    AHMEDNAGAR       1997  Summer  Maize  1100      1900.0
#  25     Maharashtra    AHMEDNAGAR       1998  Kharif  Maize  5800     12500.0
#  ...            ...           ...        ...     ...    ...   ...         ...
#  12431  Maharashtra      YAVATMAL       2010  Kharif  Maize   400      1000.0
#  12446  Maharashtra      YAVATMAL       2011  Kharif  Maize   500      1400.0
#  12462  Maharashtra      YAVATMAL       2012  Kharif  Maize   500      1100.0
#  12484  Maharashtra      YAVATMAL       2013  Summer  Maize   400       500.0
#  12494  Maharashtra      YAVATMAL       2014    Rabi  Maize  1300       200.0
#
#  [1053 rows x 7 columns],
# ...

# %%
len(info_cropwise[0].index)
# Out:
# 1053

# %%
no_of_rows = 0
i = 0
for x in info_cropwise:
  no_of_rows = len(x.index)
  print(unique_crops[i]," : ",no_of_rows)
  i += 1
  no_of_rows = 0
# Out:
# Maize  :  1053
# Pigeon Peas  :  905
# Bajra  :  384
# Gram  :  548
# Jowar  :  875
# mung bean  :  565
# Lentil  :  29
# Ragi  :  206
# Rice  :  652
# Sugarcane  :  456
# Foodgrains  :  29
# Black gram  :  548
# Chickpeas  :  296
# Wheat  :  518
# Cotton  :  465
# Castor seed  :  286
# Groundnut  :  868
# Niger seed  :  305
# Millets  :  292
# Sesamum  :  648
# Soyabean  :  477
# Sunflower  :  947
# Linseed  :  275
# Safflower  :  335
# Rapeseed  :  357
# Groundnuts  :  38
# Banana  :  28
# Grapes  :  24
# Mango  :  31
# Onion  :  26
# Tomato  :  30
# Tobacco  :  2

# %% [markdown]
# Remove following from crop yield
#
# Onion
# Jowar
# Bajara
# Ragi
# Foodgrains
# Castor seed
# Niger seed
# Sesamum
# Soyabean
# Sunflower
# Linseed
# Safflower
# Rapeseed
# Tobacco
#
# --- Gram == chick peas
#
# Remove following from crop predict
#
# Moth Beans
# Coconut
# Jute
# Peas
# Rubber
# Tobacco
# Kidney Beans
# Adzuki Beans
# muskmelon
# Orange
# Papaya
# Pomegranate
# Watermelon

# %%
## Removing unnecessary crops from dataset

removed_crops = ['Onion', 'Jowar', 'Tomato', 'Bajra', 'Ragi', 'Foodgrains', 'Castor seed', 'Niger seed', 'Sesamum', 'Soyabean', 'Sunflower', 'Linseed', 'Safflower', 'Rapeseed', 'Tobacco']

dataset_4 = dataset_3[~dataset_3.Crop.isin(removed_crops)]

# %%
unique_crops = dataset_4['Crop'].unique()
print(unique_crops)
# Out:
# ['Maize' 'Pigeon Peas' 'Gram' 'mung bean' 'Lentil' 'Rice' 'Sugarcane'
#  'Black gram' 'Chickpeas' 'Wheat' 'Cotton' 'Groundnut' 'Millets'
#  'Groundnuts' 'Banana' 'Grapes' 'Mango']

# %%
dataset_4.loc[dataset_4['Crop'] == 'Gram', ['Crop']] = 'Chick Peas'
dataset_4.loc[dataset_4['Crop'] == 'mung bean', ['Crop']] = 'Mung Beans'
dataset_4.loc[dataset_4['Crop'] == 'Black gram', ['Crop']] = 'Black Gram'
dataset_4.loc[dataset_4['Crop'] == 'Chickpeas', ['Crop']] = 'Chick Peas'
dataset_4.loc[dataset_4['Crop'] == 'Millets', ['Crop']] = 'Millet'
dataset_4.loc[dataset_4['Crop'] == 'Groundnuts', ['Crop']] = 'Groundnut'
dataset_4.loc[dataset_4['Crop'] == 'Grapes', ['Crop']] = 'Grape'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
unique_crops = dataset_4['Crop'].unique()
print(unique_crops)
# Out:
# ['Maize' 'Pigeon Peas' 'Chick Peas' 'Mung Beans' 'Lentil' 'Rice'
#  'Sugarcane' 'Black Gram' 'Wheat' 'Cotton' 'Groundnut' 'Millet' 'Banana'
#  'Grape' 'Mango']

# %%
unique_crops.sort()
print(unique_crops)
# Out:
# ['Banana' 'Black Gram' 'Chick Peas' 'Cotton' 'Grape' 'Groundnut' 'Lentil'
#  'Maize' 'Mango' 'Millet' 'Mung Beans' 'Pigeon Peas' 'Rice' 'Sugarcane'
#  'Wheat']

# %%
dataset_4.to_csv(r'Crop Sanitized .csv', index=False)

# %% [markdown]
# ## Final

# %%
dataset_5 = pd.read_csv('Crop Sanitized Updated.csv')

# %%
dataset_5.head()
# Out:
#     State_Name District_Name  Crop_Year  Season         Crop   Area  Production
# 0  Maharashtra    AHMEDNAGAR       1997  Autumn        Maize      1      1113.0
# 1  Maharashtra    AHMEDNAGAR       1997  Kharif  Pigeon Peas  17600      6300.0
# 2  Maharashtra    AHMEDNAGAR       1997  Kharif   Chick Peas  40800     18600.0
# 3  Maharashtra    AHMEDNAGAR       1997  Kharif        Maize   4400      4700.0
# 4  Maharashtra    AHMEDNAGAR       1997  Kharif   Mung Beans  10200       900.0

# %%
unique_season = dataset_5['Season'].unique()
print(unique_season)
# Out:
# ['Autumn' 'Kharif' 'Rabi' 'Summer' 'Whole Year']

# %%
unique_crops = dataset_5['Crop'].unique()
print(unique_crops)
# Out:
# ['Maize' 'Pigeon Peas' 'Chick Peas' 'Mung Beans' 'Lentil' 'Rice'
#  'Sugarcane' 'Black Gram' 'Wheat' 'Cotton' 'Groundnut' 'Millet' 'Banana'
#  'Grape' 'Mango']

# %%
info_cropwise = list()

for x in unique_crops:
  info_cropwise.append(dataset_5[dataset_5['Crop']==x])

# %%
info_cropwise
# Out:
# [       State_Name District_Name  Crop_Year  Season   Crop  Area  Production
#  0     Maharashtra    AHMEDNAGAR       1997  Autumn  Maize     1      1113.0
#  3     Maharashtra    AHMEDNAGAR       1997  Kharif  Maize  4400      4700.0
#  9     Maharashtra    AHMEDNAGAR       1997    Rabi  Maize  6200      9100.0
#  12    Maharashtra    AHMEDNAGAR       1997  Summer  Maize  1100      1900.0
#  17    Maharashtra    AHMEDNAGAR       1998  Kharif  Maize  5800     12500.0
#  ...           ...           ...        ...     ...    ...   ...         ...
#  7271  Maharashtra      YAVATMAL       2010  Kharif  Maize   400      1000.0
#  7280  Maharashtra      YAVATMAL       2011  Kharif  Maize   500      1400.0
#  7291  Maharashtra      YAVATMAL       2012  Kharif  Maize   500      1100.0
#  7306  Maharashtra      YAVATMAL       2013  Summer  Maize   400       500.0
#  7312  Maharashtra      YAVATMAL       2014    Rabi  Maize  1300       200.0
#
#  [1053 rows x 7 columns],
# ...

# %%
no_of_rows = 0
i = 0
for x in info_cropwise:
  no_of_rows = len(x.index)
  print(unique_crops[i]," : ",no_of_rows)
  i += 1
  no_of_rows = 0
# Out:
# Maize  :  1053
# Pigeon Peas  :  905
# Chick Peas  :  844
# Mung Beans  :  565
# Lentil  :  29
# Rice  :  652
# Sugarcane  :  456
# Black Gram  :  548
# Wheat  :  518
# Cotton  :  465
# Groundnut  :  906
# Millet  :  292
# Banana  :  28
# Grape  :  24
# Mango  :  31

# %%
i = 0
for x in info_cropwise:
  name = unique_crops[i]
  i += 1 
  x.to_csv(name, index=False)

# %% [markdown]
# ## More and More Preprocessing

# %%
dataset_6 = pd.read_csv("Crop Sanitized Updated-no year.csv")
dataset_6.head()
# Out:
#     State_Name District_Name  Season         Crop   Area  Production
# 0  Maharashtra    AHMEDNAGAR  Autumn        Maize      1        1113
# 1  Maharashtra    AHMEDNAGAR  Kharif  Pigeon Peas  17600        6300
# 2  Maharashtra    AHMEDNAGAR  Kharif   Chick Peas  40800       18600
# 3  Maharashtra    AHMEDNAGAR  Kharif        Maize   4400        4700
# 4  Maharashtra    AHMEDNAGAR  Kharif   Mung Beans  10200         900

# %%
seasons = dataset_6['Season'].unique()
print(seasons)
# Out:
# ['Autumn' 'Kharif' 'Rabi' 'Summer' 'Whole Year']

# %%
dataset_6.loc[dataset_6['Season'] == 'Autumn', ['Season']] = 'Rabi'

# %%
seasons = dataset_6['Season'].unique()
print(seasons)
# Out:
# ['Rabi' 'Kharif' 'Summer' 'Whole Year']

# %%
dataset_6.to_csv(r'Crop Sanitized Newly Updated .csv', index=False)

# %% [markdown]
# ## Correlation Matrix

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("crop_yield_prediction.csv")

# %%
dataset.head()
# Out:
#     State_Name District_Name  Season         Crop   Area  Production
# 0  Maharashtra    AHMEDNAGAR    Rabi        Maize      1        1113
# 1  Maharashtra    AHMEDNAGAR  Kharif  Pigeon Peas  17600        6300
# 2  Maharashtra    AHMEDNAGAR  Kharif   Chick Peas  40800       18600
# 3  Maharashtra    AHMEDNAGAR  Kharif        Maize   4400        4700
# 4  Maharashtra    AHMEDNAGAR  Kharif   Mung Beans  10200         900

# %%
dataset.columns
# Out:
# Index(['State_Name', 'District_Name', 'Season', 'Crop', 'Area', 'Production'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
  
le = LabelEncoder()
  
dataset['Crop']= le.fit_transform(dataset['Crop'])
dataset['District_Name']= le.fit_transform(dataset['District_Name'])
dataset['Season']= le.fit_transform(dataset['Season'])

# %%
dataset.head()
# Out:
#     State_Name  District_Name  Season  Crop   Area  Production
# 0  Maharashtra              0       1     7      1        1113
# 1  Maharashtra              0       0    11  17600        6300
# 2  Maharashtra              0       0     2  40800       18600
# 3  Maharashtra              0       0     7   4400        4700
# 4  Maharashtra              0       0    10  10200         900

# %%
dataset.corr()
# Out:
#                District_Name    Season      Crop      Area  Production
# District_Name       1.000000 -0.007030 -0.011366 -0.059287    0.023735
# Season             -0.007030  1.000000  0.043939 -0.136634    0.200490
# Crop               -0.011366  0.043939  1.000000 -0.032832    0.171268
# Area               -0.059287 -0.136634 -0.032832  1.000000    0.214503
# Production          0.023735  0.200490  0.171268  0.214503    1.000000

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(dataset.corr(), vmin=-1, vmax=1, annot=True)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')
